# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("==============Sales Analysis==================")

# print(sales_data.shape)
# print(sales_data.ndim)
# print(sales_data.size)

# print(sales_data)

print("The Slaes data of first three resturants are \n\n", sales_data[:,3:])

# 1/cos(x-a)*cos(x-b)

# total sales per year

print("The enrire sales aggregate of all the companies: ",np.sum(sales_data[:,1:]))

print("The sales aggrigate of year 2021: ", np.sum(sales_data[:,1],axis=0))

print("The Average sales of year 1 of all the companies is",np.average(sales_data[:,1],axis=0))

# Miniums sales per resutant

min_sales = np.min(sales_data[:,1:],axis=1)

print("The minium sales per resturant is :",min_sales)

# Maximum sales per year

print("The maximum sales per year of each resturant: ", np.max(sales_data[:,1:],axis=0))

print("The average sales of each resturant : ",np.mean(sales_data[:,1:],axis=0))

cumsum = np.cumsum(sales_data[:,1:],axis=1)
print(cumsum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis = 0))
plt.title("Average cumulative sales per year")
plt.legend()
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# ==============Sales Analysis==================
# The Slaes data of first three resturants are
#
#  [[220000 250000]
#  [160000 190000]
#  [260000 300000]
#  [240000 270000]
#  [205000 230000]]
# The enrire sales aggregate of all the companies:  4080000
# The sales aggrigate of year 2021:  810000
# The Average sales of year 1 of all the companies is 162000.0
# The minium sales per resturant is : [150000 120000 200000 180000 160000]
# The maximum sales per year of each resturant:  [200000 230000 260000 300000]
# The average sales of each resturant :  [162000. 189000. 217000. 248000.]
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]
# /tmp/ipykernel_1952/1893346003.py:48: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6,7,8,9,10])

print("Vector Addition: ",vector1+vector2)
print("Vector Multiplication: ",vector1*vector2) # automatically takes one as row and the other as coloumn

print("Dot product: ", np.dot(vector1,vector2))

angle = np.arccos(np.dot(vector1,vector2)/ (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print(angle)

resturant_types = np.array(["biryani","chinese","pizza","burger","cafe"])

vectorized_upepr = np.vectorize(str.upper)

print("Vectorized Upper", vectorized_upepr(resturant_types))

# Broadcast => 

monthly_avg = sales_data[:,1:]

print(monthly_avg / 12)
# Out:
# Vector Addition:  [ 7  9 11 13 15]
# Vector Multiplication:  [ 6 14 24 36 50]
# Dot product:  130
# 0.26554161733900966
# Vectorized Upper ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
